# %% [markdown]
# # init test AOLP or WLP

# %%
#model and weight

#weight = 'pretrained_model/best_288.pt'
#best_state_dict='pretrained_model/best_288_state_dict.pt'# cj first version

'''
dataset = /data/yolodiffusion-main/_plate/AOLP/label.txt
weight = pretrained_model/best_288_state_dict.pt
input_size = 1024
Number of Correctly Detected Plates = 2137
Number of Detected Plates = 3145
Number of All Plates = 2164
Recall = 0.9875
Precision = 0.6795
Characters in Detected Plates =  12755
Error Characters (Detected) = 1054
World Error Rate (Detected) = 0.0826

Number of Perfectly Recognized Plates =  1333
Accuracy(Detected) = 0.6238
Accuracy(Groundtruth) = 0.6160

dataset = /data/yolodiffusion-main/_plate/WLP/label.txt
weight = pretrained_model/best_288_state_dict.pt
input_size = 2048
Number of Correctly Detected Plates = 48
Number of Detected Plates = 60
Number of All Plates = 54
Recall = 0.8889
Precision = 0.8000
Characters in Detected Plates =  302
Error Characters (Detected) = 68
World Error Rate (Detected) = 0.2252

Number of Perfectly Recognized Plates =  14
Accuracy(Detected) = 0.2917
Accuracy(Groundtruth) = 0.2593
'''


#weight = 'pretrained_model/exp2_new_best_271.pt'
#best_state_dict='pretrained_model/exp2_new_best_271_state_dict.pt'# cj 0126 version
'''
dataset = /data/yolodiffusion-main/_plate/AOLP/label.txt
weight = pretrained_model/exp2_new_best_271_state_dict.pt
input_size = 1024
Number of Correctly Detected Plates = 2114
Number of Detected Plates = 4349
Number of All Plates = 2164
Recall = 0.9769
Precision = 0.4861
Characters in Detected Plates =  12616
Error Characters (Detected) = 1847
World Error Rate (Detected) = 0.1464

Number of Perfectly Recognized Plates =  1003
Accuracy(Detected) = 0.4745
Accuracy(Groundtruth) = 0.4635


dataset = /data/yolodiffusion-main/_plate/WLP/label.txt
weight = pretrained_model/exp2_new_best_271_state_dict.pt
input_size = 2048
Number of Correctly Detected Plates = 48
Number of Detected Plates = 155
Number of All Plates = 54
Recall = 0.8889
Precision = 0.3097
Characters in Detected Plates =  302
Error Characters (Detected) = 124
World Error Rate (Detected) = 0.4106

Number of Perfectly Recognized Plates =  7
Accuracy(Detected) = 0.1458
Accuracy(Groundtruth) = 0.1296

'''



#weight = 'pretrained_model/exp2new2_best_299.pt'
#best_state_dict='pretrained_model/exp2new2_best_299_state_dict.pt'# cj 0301 version
'''
dataset = /data/yolodiffusion-main/_plate/AOLP/label.txt
weight = pretrained_model/exp2new2_best_299_state_dict.pt
input_size = 1024
Number of Correctly Detected Plates = 2145
Number of Detected Plates = 3133
Number of All Plates = 2164
Recall = 0.9912
Precision = 0.6846
Characters in Detected Plates =  12801
Error Characters (Detected) = 1080
World Error Rate (Detected) = 0.0844

Number of Perfectly Recognized Plates =  1334
Accuracy(Detected) = 0.6219
Accuracy(Groundtruth) = 0.6165

dataset = /data/yolodiffusion-main/_plate/WLP/label.txt
weight = pretrained_model/exp2new2_best_299_state_dict.pt
input_size = 2048
Number of Correctly Detected Plates = 49
Number of Detected Plates = 77
Number of All Plates = 54
Recall = 0.9074
Precision = 0.6364
Characters in Detected Plates =  308
Error Characters (Detected) = 72
World Error Rate (Detected) = 0.2338

Number of Perfectly Recognized Plates =  13
Accuracy(Detected) = 0.2653
Accuracy(Groundtruth) = 0.2407
'''

#weight = 'pretrained_model/last_genbg_79.pt'
#best_state_dict='pretrained_model/last_genbg_79_state_dict.pt'
'''
dataset = /data/yolodiffusion-main/_plate/AOLP/label.txt
weight = pretrained_model/last_genbg_79_state_dict.pt
input_size = 1024
Number of Correctly Detected Plates = 2154
Number of Detected Plates = 3046
Number of All Plates = 2164
Recall = 0.9954
Precision = 0.7072
Characters in Detected Plates =  12857
Error Characters (Detected) = 423
World Error Rate (Detected) = 0.0329

Number of Perfectly Recognized Plates =  1854
Accuracy(Detected) = 0.8607
Accuracy(Groundtruth) = 0.8567

dataset = /data/yolodiffusion-main/_plate/WLP/label.txt
weight = pretrained_model/last_genbg_79_state_dict.pt
input_size = 2048
Number of Correctly Detected Plates = 48
Number of Detected Plates = 88
Number of All Plates = 54
Recall = 0.8889
Precision = 0.5455
Characters in Detected Plates =  301
Error Characters (Detected) = 89
World Error Rate (Detected) = 0.2957

Number of Perfectly Recognized Plates =  17
Accuracy(Detected) = 0.3542
Accuracy(Groundtruth) = 0.3148


'''



#weight = 'pretrained_model/last_genbg_large_angle_79.pt'
#best_state_dict='pretrained_model/last_genbg_large_angle_79_state_dict.pt'
'''
dataset = /data/yolodiffusion-main/_plate/AOLP/label.txt
weight = pretrained_model/last_genbg_large_angle_79_state_dict.pt
input_size = 1024
Number of Correctly Detected Plates = 2149
Number of Detected Plates = 3667
Number of All Plates = 2164
Recall = 0.9931
Precision = 0.5860
Characters in Detected Plates =  12829
Error Characters (Detected) = 682
World Error Rate (Detected) = 0.0532

Number of Perfectly Recognized Plates =  1692
Accuracy(Detected) = 0.7873
Accuracy(Groundtruth) = 0.7819

dataset = /data/yolodiffusion-main/_plate/WLP/label.txt
weight = pretrained_model/last_genbg_large_angle_79_state_dict.pt
input_size = 2048
Number of Correctly Detected Plates = 44
Number of Detected Plates = 80
Number of All Plates = 54
Recall = 0.8148
Precision = 0.5500
Characters in Detected Plates =  276
Error Characters (Detected) = 77
World Error Rate (Detected) = 0.2790

Number of Perfectly Recognized Plates =  13
Accuracy(Detected) = 0.2955
Accuracy(Groundtruth) = 0.2407


'''



#weight = 'static_model/real_word_079.pt'
#best_state_dict='static_model/real_word_079_state_dict.pt'
'''
dataset = /data/yolodiffusion-main/_plate/AOLP/label.txt
weight = pretrained_model/real_word_079_state_dict.pt
input_size = 1024
Number of Correctly Detected Plates = 2121
Number of Detected Plates = 2488
Number of All Plates = 2164
Recall = 0.9801
Precision = 0.8525
Characters in Detected Plates =  12658
Error Characters (Detected) = 935
World Error Rate (Detected) = 0.0739

Number of Perfectly Recognized Plates =  1396
Accuracy(Detected) = 0.6582
Accuracy(Groundtruth) = 0.6451

dataset = /data/yolodiffusion-main/_plate/WLP/label.txt
weight = pretrained_model/real_word_079_state_dict.pt
input_size = 2048
Number of Correctly Detected Plates = 47
Number of Detected Plates = 50
Number of All Plates = 54
Recall = 0.8704
Precision = 0.9400
Characters in Detected Plates =  295
Error Characters (Detected) = 86
World Error Rate (Detected) = 0.2915

Number of Perfectly Recognized Plates =  12
Accuracy(Detected) = 0.2553
Accuracy(Groundtruth) = 0.2222


'''



#weight = 'pretrained_model/genbg_with_shadow_079.pt'
#best_state_dict='pretrained_model/genbg_with_shadow_079_state_dict.pt'
'''
dataset = /data/yolodiffusion-main/_plate/AOLP/label.txt
weight = pretrained_model/genbg_with_shadow_079_state_dict.pt
input_size = 1024
Number of Correctly Detected Plates = 2138
Number of Detected Plates = 2706
Number of All Plates = 2164
Recall = 0.9880
Precision = 0.7901
Characters in Detected Plates =  12758
Error Characters (Detected) = 486
World Error Rate (Detected) = 0.0381

Number of Perfectly Recognized Plates =  1825
Accuracy(Detected) = 0.8536
Accuracy(Groundtruth) = 0.8433

dataset = /data/yolodiffusion-main/_plate/WLP/label.txt
weight = pretrained_model/genbg_with_shadow_079_state_dict.pt
input_size = 2048
Number of Correctly Detected Plates = 46
Number of Detected Plates = 58
Number of All Plates = 54
Recall = 0.8519
Precision = 0.7931
Characters in Detected Plates =  289
Error Characters (Detected) = 79
World Error Rate (Detected) = 0.2734

Number of Perfectly Recognized Plates =  16
Accuracy(Detected) = 0.3478
Accuracy(Groundtruth) = 0.2963
'''




#weight = 'pretrained_model/6th_set1_epoch_299.pt'
#best_state_dict=weight[:-3]+'_state_dict.pt'
'''
dataset = /data/yolodiffusion-main/_plate/AOLP/label.txt
weight = pretrained_model/6th_set1_epoch_299_state_dict.pt
input_size = 1024
Number of Correctly Detected Plates = 1530
Number of Detected Plates = 1642
Number of All Plates = 2164
Recall = 0.7070
Precision = 0.9318
Characters in Detected Plates =  9154
Error Characters (Detected) = 1076
World Error Rate (Detected) = 0.1175

Number of Perfectly Recognized Plates =  979
Accuracy(Detected) = 0.6399
Accuracy(Groundtruth) = 0.4524

dataset = /data/yolodiffusion-main/_plate/WLP/label.txt
weight = pretrained_model/6th_set1_epoch_299_state_dict.pt
input_size = 2048
Number of Correctly Detected Plates = 13
Number of Detected Plates = 27
Number of All Plates = 54
Recall = 0.2407
Precision = 0.4815
Characters in Detected Plates =  81
Error Characters (Detected) = 26
World Error Rate (Detected) = 0.3210

Number of Perfectly Recognized Plates =  6
Accuracy(Detected) = 0.4615
Accuracy(Groundtruth) = 0.1111

dataset = /data/yolodiffusion-main/_plate/AOLP/label.txt
weight = pretrained_model/6th_set1_epoch_299_state_dict.pt
input_size = 512
Number of Correctly Detected Plates = 1810
Number of Detected Plates = 1874
Number of All Plates = 2164
Recall = 0.8364
Precision = 0.9658
Characters in Detected Plates =  10839
Error Characters (Detected) = 1418
World Error Rate (Detected) = 0.1308

Number of Perfectly Recognized Plates =  1185
Accuracy(Detected) = 0.6547
Accuracy(Groundtruth) = 0.5476

dataset = /data/yolodiffusion-main/_plate/WLP/label.txt
weight = pretrained_model/6th_set1_epoch_299_state_dict.pt
input_size = 1024
Number of Correctly Detected Plates = 18
Number of Detected Plates = 18
Number of All Plates = 54
Recall = 0.3333
Precision = 1.0000
Characters in Detected Plates =  114
Error Characters (Detected) = 60
World Error Rate (Detected) = 0.5263

Number of Perfectly Recognized Plates =  7
Accuracy(Detected) = 0.3889
Accuracy(Groundtruth) = 0.1296

'''

#weight = 'pretrained_model/6th_set2_epoch_299.pt'
#best_state_dict=weight[:-3]+'_state_dict.pt'
'''
dataset = /data/yolodiffusion-main/_plate/AOLP/label.txt
weight = pretrained_model/6th_set2_epoch_299_state_dict.pt
input_size = 1024
Number of Correctly Detected Plates = 1638
Number of Detected Plates = 1838
Number of All Plates = 2164
Recall = 0.7569
Precision = 0.8912
Characters in Detected Plates =  9794
Error Characters (Detected) = 1449
World Error Rate (Detected) = 0.1479

Number of Perfectly Recognized Plates =  933
Accuracy(Detected) = 0.5696
Accuracy(Groundtruth) = 0.4311

dataset = /data/yolodiffusion-main/_plate/WLP/label.txt
weight = pretrained_model/6th_set2_epoch_299_state_dict.pt
input_size = 2048
Number of Correctly Detected Plates = 22
Number of Detected Plates = 41
Number of All Plates = 54
Recall = 0.4074
Precision = 0.5366
Characters in Detected Plates =  141
Error Characters (Detected) = 74
World Error Rate (Detected) = 0.5248

Number of Perfectly Recognized Plates =  7
Accuracy(Detected) = 0.3182
Accuracy(Groundtruth) = 0.1296



dataset = /data/yolodiffusion-main/_plate/AOLP/label.txt
weight = pretrained_model/6th_set2_epoch_299_state_dict.pt
input_size = 512
Number of Correctly Detected Plates = 2003
Number of Detected Plates = 2122
Number of All Plates = 2164
Recall = 0.9256
Precision = 0.9439
Characters in Detected Plates =  11986
Error Characters (Detected) = 1733
World Error Rate (Detected) = 0.1446

Number of Perfectly Recognized Plates =  1127
Accuracy(Detected) = 0.5627
Accuracy(Groundtruth) = 0.5208


dataset = /data/yolodiffusion-main/_plate/WLP/label.txt
weight = pretrained_model/6th_set2_epoch_299_state_dict.pt
input_size = 1024
Number of Correctly Detected Plates = 22
Number of Detected Plates = 23
Number of All Plates = 54
Recall = 0.4074
Precision = 0.9565
Characters in Detected Plates =  140
Error Characters (Detected) = 69
World Error Rate (Detected) = 0.4929

Number of Perfectly Recognized Plates =  5
Accuracy(Detected) = 0.2273
Accuracy(Groundtruth) = 0.0926

'''

#weight = 'pretrained_model/6th_set3_epoch_299.pt'
#best_state_dict=weight[:-3]+'_state_dict.pt'
'''
dataset = /data/yolodiffusion-main/_plate/AOLP/label.txt
weight = pretrained_model/6th_set3_epoch_299_state_dict.pt
input_size = 1024
Number of Correctly Detected Plates = 1778
Number of Detected Plates = 2046
Number of All Plates = 2164
Recall = 0.8216
Precision = 0.8690
Characters in Detected Plates =  10628
Error Characters (Detected) = 963
World Error Rate (Detected) = 0.0906

Number of Perfectly Recognized Plates =  1234
Accuracy(Detected) = 0.6940
Accuracy(Groundtruth) = 0.5702

dataset = /data/yolodiffusion-main/_plate/WLP/label.txt
weight = pretrained_model/6th_set3_epoch_299_state_dict.pt
input_size = 2048
Number of Correctly Detected Plates = 21
Number of Detected Plates = 39
Number of All Plates = 54
Recall = 0.3889
Precision = 0.5385
Characters in Detected Plates =  133
Error Characters (Detected) = 70
World Error Rate (Detected) = 0.5263

Number of Perfectly Recognized Plates =  7
Accuracy(Detected) = 0.3333
Accuracy(Groundtruth) = 0.1296



dataset = /data/yolodiffusion-main/_plate/AOLP/label.txt
weight = pretrained_model/6th_set3_epoch_299_state_dict.pt
input_size = 512
Number of Correctly Detected Plates = 2028
Number of Detected Plates = 2141
Number of All Plates = 2164
Recall = 0.9372
Precision = 0.9472
Characters in Detected Plates =  12143
Error Characters (Detected) = 1337
World Error Rate (Detected) = 0.1101

Number of Perfectly Recognized Plates =  1332
Accuracy(Detected) = 0.6568
Accuracy(Groundtruth) = 0.6155

dataset = /data/yolodiffusion-main/_plate/WLP/label.txt
weight = pretrained_model/6th_set3_epoch_299_state_dict.pt
input_size = 1024
Number of Correctly Detected Plates = 22
Number of Detected Plates = 22
Number of All Plates = 54
Recall = 0.4074
Precision = 1.0000
Characters in Detected Plates =  140
Error Characters (Detected) = 74
World Error Rate (Detected) = 0.5286

Number of Perfectly Recognized Plates =  6
Accuracy(Detected) = 0.2727
Accuracy(Groundtruth) = 0.1111



'''

#weight = 'pretrained_model/6th2_set1_epoch_299.pt'
#best_state_dict=weight[:-3]+'_state_dict.pt'
'''
dataset = /data/yolodiffusion-main/_plate/AOLP/label.txt
weight = pretrained_model/6th2_set1_epoch_299_state_dict.pt
input_size = 1024
Number of Correctly Detected Plates = 1246
Number of Detected Plates = 1331
Number of All Plates = 2164
Recall = 0.5758
Precision = 0.9361
Characters in Detected Plates =  7452
Error Characters (Detected) = 756
World Error Rate (Detected) = 0.1014

Number of Perfectly Recognized Plates =  851
Accuracy(Detected) = 0.6830
Accuracy(Groundtruth) = 0.3933

dataset = /data/yolodiffusion-main/_plate/WLP/label.txt
weight = pretrained_model/6th2_set1_epoch_299_state_dict.pt
input_size = 2048
Number of Correctly Detected Plates = 11
Number of Detected Plates = 16
Number of All Plates = 54
Recall = 0.2037
Precision = 0.6875
Characters in Detected Plates =  69
Error Characters (Detected) = 21
World Error Rate (Detected) = 0.3043

Number of Perfectly Recognized Plates =  7
Accuracy(Detected) = 0.6364
Accuracy(Groundtruth) = 0.1296


dataset = /data/yolodiffusion-main/_plate/AOLP/label.txt
weight = pretrained_model/6th2_set1_epoch_299_state_dict.pt
input_size = 512
Number of Correctly Detected Plates = 1760
Number of Detected Plates = 1908
Number of All Plates = 2164
Recall = 0.8133
Precision = 0.9224
Characters in Detected Plates =  10533
Error Characters (Detected) = 1429
World Error Rate (Detected) = 0.1357

Number of Perfectly Recognized Plates =  1123
Accuracy(Detected) = 0.6381
Accuracy(Groundtruth) = 0.5189

dataset = /data/yolodiffusion-main/_plate/WLP/label.txt
weight = pretrained_model/6th2_set1_epoch_299_state_dict.pt
input_size = 1024
Number of Correctly Detected Plates = 17
Number of Detected Plates = 19
Number of All Plates = 54
Recall = 0.3148
Precision = 0.8947
Characters in Detected Plates =  108
Error Characters (Detected) = 39
World Error Rate (Detected) = 0.3611

Number of Perfectly Recognized Plates =  8
Accuracy(Detected) = 0.4706
Accuracy(Groundtruth) = 0.1481

'''

#weight = 'pretrained_model/6th2_set2_epoch_299.pt'
#best_state_dict=weight[:-3]+'_state_dict.pt'

'''
dataset = /data/yolodiffusion-main/_plate/AOLP/label.txt
weight = pretrained_model/6th2_set2_epoch_299_state_dict.pt
input_size = 1024
Number of Correctly Detected Plates = 1331
Number of Detected Plates = 1444
Number of All Plates = 2164
Recall = 0.6151
Precision = 0.9217
Characters in Detected Plates =  7962
Error Characters (Detected) = 1006
World Error Rate (Detected) = 0.1264

Number of Perfectly Recognized Plates =  785
Accuracy(Detected) = 0.5898
Accuracy(Groundtruth) = 0.3628

dataset = /data/yolodiffusion-main/_plate/WLP/label.txt
weight = pretrained_model/6th2_set2_epoch_299_state_dict.pt
input_size = 2048
Number of Correctly Detected Plates = 15
Number of Detected Plates = 30
Number of All Plates = 54
Recall = 0.2778
Precision = 0.5000
Characters in Detected Plates =  95
Error Characters (Detected) = 25
World Error Rate (Detected) = 0.2632

Number of Perfectly Recognized Plates =  5
Accuracy(Detected) = 0.3333
Accuracy(Groundtruth) = 0.0926



dataset = /data/yolodiffusion-main/_plate/AOLP/label.txt
weight = pretrained_model/6th2_set2_epoch_299_state_dict.pt
input_size = 512
Number of Correctly Detected Plates = 1920
Number of Detected Plates = 1983
Number of All Plates = 2164
Recall = 0.8872
Precision = 0.9682
Characters in Detected Plates =  11495
Error Characters (Detected) = 1322
World Error Rate (Detected) = 0.1150

Number of Perfectly Recognized Plates =  1126
Accuracy(Detected) = 0.5865
Accuracy(Groundtruth) = 0.5203

dataset = /data/yolodiffusion-main/_plate/WLP/label.txt
weight = pretrained_model/6th2_set2_epoch_299_state_dict.pt
input_size = 1024
Number of Correctly Detected Plates = 20
Number of Detected Plates = 20
Number of All Plates = 54
Recall = 0.3704
Precision = 1.0000
Characters in Detected Plates =  127
Error Characters (Detected) = 57
World Error Rate (Detected) = 0.4488

Number of Perfectly Recognized Plates =  5
Accuracy(Detected) = 0.2500
Accuracy(Groundtruth) = 0.0926

'''

#weight = 'pretrained_model/6th2_set3_epoch_299.pt'
#best_state_dict=weight[:-3]+'_state_dict.pt'
'''
dataset = /data/yolodiffusion-main/_plate/AOLP/label.txt
weight = pretrained_model/6th2_set3_epoch_299_state_dict.pt
input_size = 1024
Number of Correctly Detected Plates = 1357
Number of Detected Plates = 1429
Number of All Plates = 2164
Recall = 0.6271
Precision = 0.9496
Characters in Detected Plates =  8109
Error Characters (Detected) = 1050
World Error Rate (Detected) = 0.1295

Number of Perfectly Recognized Plates =  840
Accuracy(Detected) = 0.6190
Accuracy(Groundtruth) = 0.3882

dataset = /data/yolodiffusion-main/_plate/WLP/label.txt
weight = pretrained_model/6th2_set3_epoch_299_state_dict.pt
input_size = 2048
Number of Correctly Detected Plates = 13
Number of Detected Plates = 27
Number of All Plates = 54
Recall = 0.2407
Precision = 0.4815
Characters in Detected Plates =  82
Error Characters (Detected) = 26
World Error Rate (Detected) = 0.3171

Number of Perfectly Recognized Plates =  5
Accuracy(Detected) = 0.3846
Accuracy(Groundtruth) = 0.0926

dataset = /data/yolodiffusion-main/_plate/AOLP/label.txt
weight = pretrained_model/6th2_set3_epoch_299_state_dict.pt
input_size = 512
Number of Correctly Detected Plates = 1924
Number of Detected Plates = 1989
Number of All Plates = 2164
Recall = 0.8891
Precision = 0.9673
Characters in Detected Plates =  11517
Error Characters (Detected) = 1644
World Error Rate (Detected) = 0.1427

Number of Perfectly Recognized Plates =  1194
Accuracy(Detected) = 0.6206
Accuracy(Groundtruth) = 0.5518

dataset = /data/yolodiffusion-main/_plate/WLP/label.txt
weight = pretrained_model/6th2_set3_epoch_299_state_dict.pt
input_size = 1024
Number of Correctly Detected Plates = 18
Number of Detected Plates = 19
Number of All Plates = 54
Recall = 0.3333
Precision = 0.9474
Characters in Detected Plates =  114
Error Characters (Detected) = 53
World Error Rate (Detected) = 0.4649

Number of Perfectly Recognized Plates =  6
Accuracy(Detected) = 0.3333
Accuracy(Groundtruth) = 0.1111
'''



#weight = 'pretrained_model/gaussianyolo_epoch_024.pt'
#best_state_dict=weight[:-3]+'_state_dict.pt'
'''
dataset = /data/yolodiffusion-main/_plate/AOLP/label.txt
weight = pretrained_model/gaussianyolo_epoch_024_state_dict.pt
input_size = 512
Number of Correctly Detected Plates = 2117
Number of Detected Plates = 3815
Number of All Plates = 2164
Recall = 0.9783
Precision = 0.5549
Characters in Detected Plates =  12648
Error Characters (Detected) = 1101
World Error Rate (Detected) = 0.0870

Number of Perfectly Recognized Plates =  1379
Accuracy(Detected) = 0.6514
Accuracy(Groundtruth) = 0.6372


dataset = /data/yolodiffusion-main/_plate/WLP/label.txt
weight = pretrained_model/gaussianyolo_epoch_024_state_dict.pt
input_size = 1024
Number of Correctly Detected Plates = 38
Number of Detected Plates = 105
Number of All Plates = 54
Recall = 0.7037
Precision = 0.3619
Characters in Detected Plates =  237
Error Characters (Detected) = 153
World Error Rate (Detected) = 0.6456

Number of Perfectly Recognized Plates =  2
Accuracy(Detected) = 0.0526
Accuracy(Groundtruth) = 0.0370


dataset = /data/yolodiffusion-main/_plate/AOLP/label.txt
weight = pretrained_model/gaussianyolo_epoch_024_state_dict.pt
input_size = 1024
Number of Correctly Detected Plates = 2154
Number of Detected Plates = 4577
Number of All Plates = 2164
Recall = 0.9954
Precision = 0.4706
Characters in Detected Plates =  12852
Error Characters (Detected) = 629
World Error Rate (Detected) = 0.0489

Number of Perfectly Recognized Plates =  1715
Accuracy(Detected) = 0.7962
Accuracy(Groundtruth) = 0.7925

dataset = /data/yolodiffusion-main/_plate/WLP/label.txt
weight = pretrained_model/gaussianyolo_epoch_024_state_dict.pt
input_size = 2048
Number of Correctly Detected Plates = 48
Number of Detected Plates = 214
Number of All Plates = 54
Recall = 0.8889
Precision = 0.2243
Characters in Detected Plates =  301
Error Characters (Detected) = 93
World Error Rate (Detected) = 0.3090

Number of Perfectly Recognized Plates =  17
Accuracy(Detected) = 0.3542
Accuracy(Groundtruth) = 0.3148


'''

#weight = 'pretrained_model/gaussianyolo_max_1000_20_epoch_019.pt'
#best_state_dict=weight[:-3]+'_state_dict.pt'
'''
dataset = /data/yolodiffusion-main/_plate/AOLP/label.txt
weight = pretrained_model/gaussianyolo_max_1000_20_epoch_019_state_dict.pt
input_size = 512
Number of Correctly Detected Plates = 2103
Number of Detected Plates = 2787
Number of All Plates = 2164
Recall = 0.9718
Precision = 0.7546
Characters in Detected Plates =  12584
Error Characters (Detected) = 1064
World Error Rate (Detected) = 0.0846

Number of Perfectly Recognized Plates =  1390
Accuracy(Detected) = 0.6610
Accuracy(Groundtruth) = 0.6423

dataset = /data/yolodiffusion-main/_plate/WLP/label.txt
weight = pretrained_model/gaussianyolo_max_1000_20_epoch_019_state_dict.pt
input_size = 1024
Number of Correctly Detected Plates = 36
Number of Detected Plates = 55
Number of All Plates = 54
Recall = 0.6667
Precision = 0.6545
Characters in Detected Plates =  226
Error Characters (Detected) = 135
World Error Rate (Detected) = 0.5973

Number of Perfectly Recognized Plates =  6
Accuracy(Detected) = 0.1667
Accuracy(Groundtruth) = 0.1111


dataset = /data/yolodiffusion-main/_plate/AOLP/label.txt
weight = pretrained_model/gaussianyolo_max_1000_20_epoch_019_state_dict.pt
input_size = 1024
Number of Correctly Detected Plates = 2149
Number of Detected Plates = 3726
Number of All Plates = 2164
Recall = 0.9931
Precision = 0.5768
Characters in Detected Plates =  12829
Error Characters (Detected) = 700
World Error Rate (Detected) = 0.0546

Number of Perfectly Recognized Plates =  1666
Accuracy(Detected) = 0.7752
Accuracy(Groundtruth) = 0.7699

dataset = /data/yolodiffusion-main/_plate/WLP/label.txt
weight = pretrained_model/gaussianyolo_max_1000_20_epoch_019_state_dict.pt
input_size = 2048
Number of Correctly Detected Plates = 47
Number of Detected Plates = 93
Number of All Plates = 54
Recall = 0.8704
Precision = 0.5054
Characters in Detected Plates =  295
Error Characters (Detected) = 100
World Error Rate (Detected) = 0.3390

Number of Perfectly Recognized Plates =  12
Accuracy(Detected) = 0.2553
Accuracy(Groundtruth) = 0.2222


'''



#weight = 'static_model/randomreal_epoch_049.pt'
#best_state_dict=weight[:-3]+'_state_dict.pt'
'''
dataset = /data/licence_plate/_plate/AOLP/label.txt
weight = static_model/randomreal_epoch_049_state_dict.pt
input_size = 512
Number of Correctly Detected Plates = 2096
Number of Detected Plates = 2636
Number of All Plates = 2164
Recall = 0.9686
Precision = 0.7951
Characters in Detected Plates =  12531
Error Characters (Detected) = 998
World Error Rate (Detected) = 0.0796

Number of Perfectly Recognized Plates =  1484
Accuracy(Detected) = 0.7080
Accuracy(Groundtruth) = 0.6858

dataset = /data/licence_plate/_plate/WLP/label.txt
weight = static_model/randomreal_epoch_049_state_dict.pt
input_size = 1024
Number of Correctly Detected Plates = 37
Number of Detected Plates = 47
Number of All Plates = 54
Recall = 0.6852
Precision = 0.7872
Characters in Detected Plates =  233
Error Characters (Detected) = 112
World Error Rate (Detected) = 0.4807

Number of Perfectly Recognized Plates =  8
Accuracy(Detected) = 0.2162
Accuracy(Groundtruth) = 0.1481



dataset = /data/licence_plate/_plate/AOLP/label.txt
weight = static_model/randomreal_epoch_049_state_dict.pt
input_size = 1024
Number of Correctly Detected Plates = 2124
Number of Detected Plates = 2661
Number of All Plates = 2164
Recall = 0.9815
Precision = 0.7982
Characters in Detected Plates =  12678
Error Characters (Detected) = 605
World Error Rate (Detected) = 0.0477

Number of Perfectly Recognized Plates =  1712
Accuracy(Detected) = 0.8060
Accuracy(Groundtruth) = 0.7911

dataset = /data/licence_plate/_plate/WLP/label.txt
weight = static_model/randomreal_epoch_049_state_dict.pt
input_size = 2048
Number of Correctly Detected Plates = 46
Number of Detected Plates = 76
Number of All Plates = 54
Recall = 0.8519
Precision = 0.6053
Characters in Detected Plates =  288
Error Characters (Detected) = 87
World Error Rate (Detected) = 0.3021

Number of Perfectly Recognized Plates =  17
Accuracy(Detected) = 0.3696
Accuracy(Groundtruth) = 0.3148

'''

#weight = 'static_model/randomreal_epoch_079.pt'
#best_state_dict=weight[:-3]+'_state_dict.pt'
'''
dataset = /data/licence_plate/_plate/AOLP/label.txt
weight = static_model/randomreal_epoch_079_state_dict.pt
input_size = 1024
Number of Correctly Detected Plates = 2145
Number of Detected Plates = 2961
Number of All Plates = 2164
Recall = 0.9912
Precision = 0.7244
Characters in Detected Plates =  12802
Error Characters (Detected) = 533
World Error Rate (Detected) = 0.0416

Number of Perfectly Recognized Plates =  1786
Accuracy(Detected) = 0.8326
Accuracy(Groundtruth) = 0.8253

dataset = /data/licence_plate/_plate/WLP/label.txt
weight = static_model/randomreal_epoch_079_state_dict.pt
input_size = 2048
Number of Correctly Detected Plates = 48
Number of Detected Plates = 80
Number of All Plates = 54
Recall = 0.8889
Precision = 0.6000
Characters in Detected Plates =  301
Error Characters (Detected) = 85
World Error Rate (Detected) = 0.2824

Number of Perfectly Recognized Plates =  17
Accuracy(Detected) = 0.3542
Accuracy(Groundtruth) = 0.3148

'''
#weight = 'static_model/real_epoch_079.pt'
#best_state_dict=weight[:-3]+'_state_dict.pt'

'''
dataset = /data/licence_plate/_plate/AOLP/label.txt
weight = static_model/real_epoch_079_state_dict.pt
input_size = 1024
Number of Correctly Detected Plates = 2121
Number of Detected Plates = 2488
Number of All Plates = 2164
Recall = 0.9801
Precision = 0.8525
Characters in Detected Plates =  12658
Error Characters (Detected) = 935
World Error Rate (Detected) = 0.0739


Number of Perfectly Recognized Plates =  1396
Accuracy(Detected) = 0.6582
Accuracy(Groundtruth) = 0.6451

dataset = /data/licence_plate/_plate/WLP/label.txt
weight = static_model/real_epoch_079_state_dict.pt
input_size = 2048
Number of Correctly Detected Plates = 47
Number of Detected Plates = 50
Number of All Plates = 54
Recall = 0.8704
Precision = 0.9400
Characters in Detected Plates =  295
Error Characters (Detected) = 86
World Error Rate (Detected) = 0.2915

Number of Perfectly Recognized Plates =  12
Accuracy(Detected) = 0.2553
Accuracy(Groundtruth) = 0.2222


'''


#weight = 'static_model/yolov7_tiny_real_shadow_epoch_079.pt'
#best_state_dict=weight[:-3]+'_state_dict.pt'

#weight = 'static_model/yolov7-tiny-genbg-ep20-b64-blur_epoch_019.pt'
#best_state_dict=weight[:-3]+'_state_dict.pt'

'''
dataset = /data/licence_plate/_plate/AOLP/label.txt
weight = static_model/yolov7-tiny-genbg-ep20-b64-blur_epoch_019_state_dict.pt
input_size = 1024
Number of Correctly Detected Plates = 2073
Number of Detected Plates = 2925
Number of All Plates = 2164
Recall = 0.9579
Precision = 0.7087
Characters in Detected Plates =  12377
Error Characters (Detected) = 832
World Error Rate (Detected) = 0.0672

Number of Perfectly Recognized Plates =  1547
Accuracy(Detected) = 0.7463
Accuracy(Groundtruth) = 0.7149



dataset = /data/licence_plate/_plate/WLP/label.txt
weight = static_model/yolov7-tiny-genbg-ep20-b64-glur_epoch_019_state_dict.pt
input_size = 2048
Number of Correctly Detected Plates = 45
Number of Detected Plates = 84
Number of All Plates = 54
Recall = 0.8333
Precision = 0.5357
Characters in Detected Plates =  283
Error Characters (Detected) = 103
World Error Rate (Detected) = 0.3640

Number of Perfectly Recognized Plates =  11
Accuracy(Detected) = 0.2444
Accuracy(Groundtruth) = 0.2037

'''



weight = 'static_model/yolov7-tiny-genbg-ep20-b64-gamma_epoch_019.pt'

'''
dataset = /data/licence_plate/_plate/AOLP/label.txt
weight = static_model/yolov7-tiny-genbg-ep20-b64-gamma_epoch_019_state_dict.pt
input_size = 1024
Number of Correctly Detected Plates = 2051
Number of Detected Plates = 2507
Number of All Plates = 2164
Recall = 0.9478
Precision = 0.8181
Characters in Detected Plates =  12247
Error Characters (Detected) = 1012
World Error Rate (Detected) = 0.0826

Number of Perfectly Recognized Plates =  1491
Accuracy(Detected) = 0.7270
Accuracy(Groundtruth) = 0.6890


dataset = /data/licence_plate/_plate/WLP/label.txt
weight = static_model/yolov7-tiny-genbg-ep20-b64-gamma_epoch_019_state_dict.pt
input_size = 2048
Number of Correctly Detected Plates = 43
Number of Detected Plates = 57
Number of All Plates = 54
Recall = 0.7963
Precision = 0.7544
Characters in Detected Plates =  270
Error Characters (Detected) = 122
World Error Rate (Detected) = 0.4519

Number of Perfectly Recognized Plates =  10
Accuracy(Detected) = 0.2326
Accuracy(Groundtruth) = 0.1852
'''


#dataset

#AOLP
#label_txt = '/data/yolodiffusion-main/_plate/AOLP/label.txt'
#img_dir = '/data/yolodiffusion-main/_plate/AOLP/original/'
#input_size = 1024


#WLP
#label_txt = '/data/yolodiffusion-main/_plate/WLP/label.txt'
#img_dir = '/data/yolodiffusion-main/_plate/WLP/original/'
#input_size = 2048


#conf_thres = 0.001
#iou_thres = 0.6
conf_thres = 0.5
iou_thres = 0.5

# %%
'''
# from weight.pt get state and dict
#weight = 'pretrained_model/6th_set1_epoch_299.pt'
#weight = 'pretrained_model/6th_set2_epoch_299.pt'
#weight = 'pretrained_model/6th_set3_epoch_299.pt'
#weight = 'pretrained_model/6th2_set1_epoch_299.pt'
#weight = 'pretrained_model/6th2_set2_epoch_299.pt'
#weight = 'pretrained_model/6th2_set3_epoch_299.pt'
#weight = 'pretrained_model/gaussianyolo_epoch_024.pt'
#weight = 'pretrained_model/gaussianyolo_max_1000_20_epoch_019.pt'
#weight = 'static_model/randomreal_epoch_049.pt'
#weight = 'static_model/yolov7_tiny_real_shadow_epoch_079.pt'
#weight = 'static_model/yolov7-tiny-genbg-ep20-b64-glur_epoch_019.pt'
#weight = 'static_model/yolov7-tiny-genbg-ep20-b64-gamma_epoch_019.pt'




best_state_dict=weight[:-3]+'_state_dict.pt'# cj 0301 version

import torch
device = 'cuda:2'

checkpoint = torch.load(weight)
print(checkpoint.keys())
if 'epoch' in checkpoint.keys():
    print('Loaded {}, epoch {}'.format(weight, checkpoint['epoch']))
model = checkpoint['model'].cuda().to(device)#.half()

model.eval()
for param in model.parameters():
    param.requires_grad=False

print(weight[:-3]+'_state_dict.pt')
torch.save(model.state_dict(),weight[:-3]+'_state_dict.pt')
'''
# Out:
# dict_keys(['epoch', 'best_fitness', 'training_results', 'model', 'ema', 'updates', 'optimizer', 'wandb_id'])
# Loaded static_model/yolov7-tiny-genbg-ep20-b64-gamma_epoch_019.pt, epoch 19
# static_model/yolov7-tiny-genbg-ep20-b64-gamma_epoch_019_state_dict.pt

# %%
import os
import cv2
import numpy as np
import torch
import torch.utils.data
import torch.nn as nn
import yaml
import math
from tqdm import tqdm

from utils.general import non_max_suppression
from utils.augmentations import mix_augmentaion
import sys
#sys.path.append('/data/yolodiffusion-main/Cold-Diffusion-Models/licenceplate_deaug_yolov7_pytorch/')
#sys.path.append('/data/yolodiffusion-main/Cold-Diffusion-Models/licenceplate_deaug_yolov7_pytorch/')
sys.path.append('/data/licence_plate/Cold-Diffusion-Models/licenceplate_deaug_yolov7_pytorch/')

from licenceplate_deaug_pytorch.licenceplate_deaug_pytorch_aug_in_dataloader import Unet, GaussianDiffusion, Trainer

data = 'data/plate.yaml'
device = 'cuda:2'
aug_licence = mix_augmentaion()

with open(data) as f:
    data = yaml.load(f, Loader=yaml.FullLoader)
classes = data['names']

checkpoint = torch.load(weight)
print('Loaded {}, epoch {}'.format(weight, checkpoint['epoch']))
model = checkpoint['model'].cuda().to(device)#.half()

model.eval()
#torch.save(model.state_dict(),'runs/train/exp2/weights/best_288_state_dict.pt')
#print(model.forward_two)
from models.yolo_with_diffusion import Model_with_diffusion

#cfgyolotiny='/data/yolodiffusion-main/_yolo/yolov7/cfg/training/yolov7-tiny.yaml'
#hypyolotiny='/data/yolodiffusion-main/_yolo/yolov7/cfg/deploy/hyp.scratch.tiny.yaml'

cfgyolotiny='/data/licence_plate/_yolo/yolov7/cfg/training/yolov7-tiny.yaml'
hypyolotiny='/data/licence_plate/_yolo/yolov7/cfg/deploy/hyp.scratch.tiny.yaml'

nc=35
with open(hypyolotiny) as f:
    hyp = yaml.load(f, Loader=yaml.SafeLoader)  # load hyps

model = Model_with_diffusion(cfgyolotiny, ch=3, nc=nc, anchors=hyp.get('anchors')).to(device)#.half()  # create
#ptmodel=torch.load(best_state_dict)
#print(ptmodel.keys())

model.load_state_dict(torch.load(best_state_dict),strict=False)# if model have some changes please set strict=False
model.eval()
#print(model.m)

#model_path='/data/data/yolodiffusion/Cold-Diffusion-Models/licenceplate_deaug_yolov7_pytorch/latent_yolov7_1024_aug_from_dataloader_train/model.pt'


#data_path='/data/yolodiffusion-main/_plate/AOLP/original/'
data_path='/data/licence_plate/_plate/generated_data/result2/img/'



'''
diffusionmodel = Unet(
    dim = 64,
    dim_mults = (1, 2, 4, 8),
    channels=128,
    with_time_emb=not(False),
    residual=False
).cuda().to(device)#.half()

diffusion = GaussianDiffusion(
    diffusionmodel,
    image_size = 128,
    device_of_kernel = 'cuda',
    channels = 128,
    timesteps = 100,        # number of steps
    loss_type = 'l1',                   # L1 or L2
    aug_routine='Default',
    train_routine = 'Final',
    sampling_routine = 'x0_step_down',
    yolomodel=model
).cuda().to(device)#.half()


diffusion = torch.nn.DataParallel(diffusion, device_ids=range(torch.cuda.device_count()))


diffusion_trainer = Trainer(
    diffusion,
    [data_path],
    image_size = 1024,
    train_batch_size = 8,
    train_lr = 2e-5,
    train_num_steps = 700000, # total training steps
    gradient_accumulate_every = 2,      # gradient accumulation steps
    ema_decay = 0.995,                  # exponential moving average decay
    fp16 = False,                       # turn on mixed precision training with apex
    results_folder = './',
    load_path = model_path,
    dataset = 'AOLP',
    test_mode=True
)
'''

def diffusion_load(load_path,model,ema_model):
    print("Loading : ", load_path)
    data = torch.load(load_path)
    #print(data['ema'])
    #model.load_state_dict(data['model'],strict=False)
    #ema_model.load_state_dict(data['ema'])
    return data['ema']
#ddd = diffusion_load(model_path,_,_)
#print(diffusion.keys())

#print(ddd.keys())
#diffusion_model = diffusion_trainer.ema_model
#denoise_fn
#yolomodel
#module.denoise_fn
#module.yolomodel


#module.denoise_fn
#module.yolomodel
def resize(img, size):
    h, w, c = img.shape
    if not (h == size and w == size):
        img = img.copy()
        scale_x = float(size / w)
        scale_y = float(size / h)
        ratio = min(scale_x, scale_y)
        nw, nh = int(w*ratio), int(h*ratio)
        new_img = cv2.resize(img, (nw, nh))

        blank = np.zeros((size, size, c))
        dw, dh = (size-nw)//2, (size-nh)//2
        blank[dh: dh+nh, dw: dw+nw] = new_img
        meta = {'nw': nw, 'nh': nh, 'dw': dw, 'dh': dh, 'w': w, 'h': h}
        return blank, meta
    else:
        meta = {}
        return img, meta

def warp_affine(pt, M):
    new_pt = np.array([pt[0], pt[1], 1.], dtype=np.float32).T
    new_pt = np.dot(M, new_pt)
    return new_pt

def affine_transform(dets, meta):
    '''
    Transfer input-sized perdictions to original-sized coordinate. (Anchor)
    Input:
        dets = [1(batch), num_objs, 6(x1, y1, x2, y2, conf, cls)]
        meta = {'nw': resize_w, 
                'nh': resize_h, 
                'dw': offset_w, 
                'dh': offset_h, 
                'w': original_size_w, 
                'h': original_size_h}
    '''
    dets = np.array([x.cpu().numpy() for x in dets[0]])
    if len(meta)>0:
        p1 = np.float32([[0, 0], [0, meta['nh']], [meta['nw'], 0]])
        p2 = np.float32([[0, 0], [0, meta['h']], [meta['w'], 0]])
        M = cv2.getAffineTransform(p1, p2)

        for i in range(dets.shape[0]):
            dets[i, 0] -= meta['dw']
            dets[i, 1] -= meta['dh']
            dets[i, 2] -= meta['dw']
            dets[i, 3] -= meta['dh']

            dets[i, 0:2] = warp_affine(dets[i, 0:2], M)
            dets[i, 2:4] = warp_affine(dets[i, 2:4], M)
        return dets
    else:
        return dets

def preproccess_img(img_path):
    img = cv2.imread(img_path)
    img, meta = resize(img, input_size)
    img = (img / 255.).astype(np.float32)
    img = img[:, :, ::-1].transpose(2, 0, 1)  # BGR to RGB, to 3x512x512
    img = np.ascontiguousarray(img)
    img = torch.from_numpy(img).to(device)
    img = torch.unsqueeze(img, 0)
    #img = img.half()
    return img, meta

def run(img_path):
    '''
    Return: output = [num_objs, 6(x1, y1, x2, y2, conf, cls)]
    '''
    img, meta = preproccess_img(img_path)
    with torch.no_grad():
        ret = model(img)
        ret = non_max_suppression(ret[0], conf_thres=conf_thres, iou_thres=iou_thres, labels=[], multi_label=True)
    return ret, meta

def run_test_bfaf(img_path):
    '''
    Return: output = [num_objs, 6(x1, y1, x2, y2, conf, cls)]
    '''
    img, meta = preproccess_img(img_path)
    with torch.no_grad():
        ret1 = model(img)
        #ret1 = non_max_suppression(ret1[0], conf_thres=conf_thres, iou_thres=iou_thres, labels=[], multi_label=True)

        ret2_bf,y = model.forward_submodel(img,model.before_diffusion_model,output_y=True)
        print(ret2_bf)
        ret2 = model.forward_submodel(ret2_bf,model.after_diffusion_model,init_y=y)
        #ret2 = non_max_suppression(ret2[0], conf_thres=conf_thres, iou_thres=iou_thres, labels=[], multi_label=True)
    return ret1, ret2, meta

def run_withdiffusion(img_path,times=100):
    '''
    Return: output = [num_objs, 6(x1, y1, x2, y2, conf, cls)]
    '''
    img, meta = preproccess_img(img_path)
    with torch.no_grad():
        ret_bf,y = model.forward_submodel(img,model.before_diffusion_model,output_y=True)
        batch_size = ret_bf.shape[0]
        step = torch.full((batch_size,), times - 1, dtype=torch.long).cuda().to(device)#.half()
        
        ret_diffusion = diffusion_trainer.model.module.denoise_fn(ret_bf,step)
        
        #print('ret_bf = '+str(torch.mean(ret_bf))+str(torch.min(ret_bf))+str(torch.max(ret_bf)))
        #print('ret_diffusion = '+str(torch.mean(ret_diffusion))+str(torch.min(ret_diffusion))+str(torch.max(ret_diffusion)))

        #ret_diffusion = ret_bf
        y[-1]=ret_diffusion
        ret = model.forward_submodel(ret_diffusion,model.after_diffusion_model,init_y=y)
        #print(ret[0].shape)
        #print(ret[1][0].shape)
        #print(ret[1][1].shape)
        #print(ret[1][2].shape)

        ret = non_max_suppression(ret[0], conf_thres=conf_thres, iou_thres=iou_thres, labels=[], multi_label=True)
    return ret, meta

def run_withdiffusion_ema(img_path,times=100):
    '''
    Return: output = [num_objs, 6(x1, y1, x2, y2, conf, cls)]
    '''
    img, meta = preproccess_img(img_path)
    with torch.no_grad():
        ret_bf,y = model.forward_submodel(img,model.before_diffusion_model,output_y=True)
        batch_size = ret_bf.shape[0]
        step = torch.full((batch_size,), times - 1, dtype=torch.long).cuda().to(device)#.half()
        
        ret_diffusion = diffusion_trainer.ema_model.module.denoise_fn(ret_bf,step)
        
        #print('ret_bf = '+str(torch.mean(ret_bf))+str(torch.min(ret_bf))+str(torch.max(ret_bf)))
        #print('ret_diffusion = '+str(torch.mean(ret_diffusion))+str(torch.min(ret_diffusion))+str(torch.max(ret_diffusion)))

        #ret_diffusion = ret_bf
        y[-1]=ret_diffusion
        ret = model.forward_submodel(ret_diffusion,model.after_diffusion_model,init_y=y)
        ret = non_max_suppression(ret[0], conf_thres=conf_thres, iou_thres=iou_thres, labels=[], multi_label=True)
    return ret, meta


def run_aug_withdiffusion(img_path,times=100,ratio=1.0):
    '''
    Return: output = [num_objs, 6(x1, y1, x2, y2, conf, cls)]
    '''
    img, meta = preproccess_img(img_path)
    img = aug_licence.batch_data_add_licence_aug(img, ratio)

    with torch.no_grad():
        ret_bf,y = model.forward_submodel(img,model.before_diffusion_model,output_y=True)
        batch_size = ret_bf.shape[0]
        step = torch.full((batch_size,), times - 1, dtype=torch.long).cuda().to(device)#.half()
        
        #ret_diffusion = diffusion.denoise_fn(ret_bf, step)
        ret_diffusion = diffusion_trainer.model.module.denoise_fn(ret_bf,step)
        
        y[-1]=ret_diffusion
        ret = model.forward_submodel(ret_diffusion,model.after_diffusion_model,init_y=y)
        ret = non_max_suppression(ret[0], conf_thres=conf_thres, iou_thres=iou_thres, labels=[], multi_label=True)
    return ret, meta



def run_aug(img_path,ratio=1.0):
    '''
    Return: output = [num_objs, 6(x1, y1, x2, y2, conf, cls)]
    '''
    img, meta = preproccess_img(img_path)
    b, c, h, w = img.shape
    aug_licence.imshape=[h,w]
    aug_licence.random_parameter()

    img = aug_licence.batch_data_add_licence_aug(img, ratio)
    with torch.no_grad():
        ret = model(img)
        ret = non_max_suppression(ret[0], conf_thres=conf_thres, iou_thres=iou_thres, labels=[], multi_label=True)
    return ret, meta

#==================================================================

def transfer_label(lab):
    '''
    Transfer label(string) into list(int).
    Input:
        lab: string list ['x_min,y_min,x_max,y_max,plate']
            i.e. ['14,71,83,105,FS799', '215,188,324,240,DP4846']
    Return:
        new_lab: int list [x_min, y_min, x_max, y_max]
            i.e. [[14,71,83,105], [215,188,324,240]]
    '''
    new_lab = []
    for l in lab:
        _l = l.split(',')
        x1 = int(_l[0])
        y1 = int(_l[1])
        x2 = int(_l[2])
        y2 = int(_l[3])
        new_lab.append([x1, y1, x2, y2])
    
    return new_lab

def get_iou(bb1, bb2):
    '''
    Input:
        bb1(groundtruth) = [left_top_x, y, right_bottom_x, y]
        bb2(predict_point) = [left_top_x, y, right_bottom_x, y]
    '''
    x_left = max(bb1[0], bb2[0])
    y_top = max(bb1[1], bb2[1])
    x_right = min(bb1[2], bb2[2])
    y_bottom = min(bb1[3], bb2[3])

    if x_right < x_left or y_bottom < y_top:
        return 0.0

    intersection_area = (x_right - x_left) * (y_bottom - y_top)

    bb1_area = (bb1[2] - bb1[0]) * (bb1[3] - bb1[1])
    bb2_area = (bb2[2] - bb2[0]) * (bb2[3] - bb2[1])

    iou = intersection_area / float(bb1_area + bb2_area - intersection_area)
    assert iou >= 0.0
    assert iou <= 1.0
    return iou

def check_bbox(bb1, bb2):
    '''
    Check if the center point of bb2 is within bb1.
    If so, return True, otherwise return False.
    Input:
        bb1(large region) = [x_min, y_min, x_max, y_max] (all int)
        bb2(small region) = [x_min, y_min, x_max, y_max] (all int)
    '''
    # Assert bb1 is the larger one
    bb1_area = (bb1[2] - bb1[0]) * (bb1[3] - bb1[1])
    bb2_area = (bb2[2] - bb2[0]) * (bb2[3] - bb2[1])
    if bb1_area < bb2_area:
        temp = bb2
        bb2 = bb1
        bb1 = temp
        
    b2cx = (bb2[0] + bb2[2]) / 2
    b2cy = (bb2[1] + bb2[3]) / 2
    
    f1 = (bb1[0] < b2cx < bb1[2])
    f2 = (bb1[1] < b2cy < bb1[3])
    if f1 and f2:
        return True
    else:
        return False
    
#     f1 = bb1[0] <= bb2[0]
#     f2 = bb1[1] <= bb2[1]
#     f3 = bb1[2] >= bb2[2]
#     f4 = bb1[3] >= bb2[3]

#     if f1 and f2 and f3 and f4:
#         return True
#     else:
#         return False


def group_plate(outp):
    '''
    Group each character into seperate plates.
    Input:
        outp = float[[x1, y1, x2, y2, score, class], ...]
            i.e. [[     40.859      162.66      142.42      216.09      0.9668          34]
                  [     125.08      178.28      138.83      208.91     0.93213           6]
                  [         95      176.41      110.94      207.03      0.9248           8]
                  [     110.16      177.34      125.16      208.28     0.91211           8]
                  [     80.156      175.47      97.344      206.72     0.90674           4]
                  [     45.039      173.44      64.414         205     0.89111          13]
                  [     60.078      174.06      78.828      205.62     0.81445          17]]
    Return: 
        a sorted list of dict [{'plate': int[x1, y1, x2, y2], 'char':[int[x1, y1, x2, y2, idx], ...]}, ...]
             i.e. [{'plate': [40, 162, 142, 216], 
                    'char':  [[45, 173, 64, 205, 13],
                             [60, 174, 78, 205, 17],
                             [80, 175, 97, 206, 4],
                             [95, 176, 110, 207, 8],
                             [110, 177, 125, 208, 8],
                             [125, 178, 138, 208, 6]]}]
    '''
    plates = []
    chars = []
    groups = []
    for obj in outp:
        if int(obj[-1]) == 34:
            pla = [int(p) for p in obj[:4]]
            group = {'plate': pla, 'char':[]}
            groups.append(group)
        else:
            chars.append(obj)
    for obj in chars:
        cha = [int(obj[0]), int(obj[1]), int(obj[2]), int(obj[3]), int(obj[5])]
        for g in groups:
            pla = g['plate']
            if check_bbox(pla, cha[:4]):
                g['char'].append(cha)
    ### Sort list
    for g in groups:
        g['char'] = sorted(g['char'], key=lambda x: x[0])
    return groups

def get_str(chars):
    '''
    Create plate string from indivisual detected character.
    Input:
        chars = a sorted list [int[x1, y1, x2, y2, idx], ...]]
    Return:
        plate_str = plate string, i.e. 'DH4886'
    '''
    s = ''
    for o in chars:
        c = o[-1]
        s += classes[c]
    return s

def get_acc(inp, outp):
    """
    Compute two strings character by character.
    Input:
        inp: ground truth(str)
        outp: detected result(str)
    Return:
        m: number of groundtruth(int)
        count: number of detect correctly(int)
    """
    m = len(inp)
    count = sum((Counter(inp) & Counter(outp)).values())
    return m, count

def compute_acc(outp, labels):
    '''
    Compute accuracy between detected results and labels.
    Input:
        outp = a list of dic [{'plate': int[x1, y1, x2, y2], 'char':[int[x1, y1, x2, y2, idx], ...]}, ...]
        labels = a list of str, i.e. ['14,71,83,105,FS799', '215,188,324,240,DP4846']
    Return:
        total = the number of all characters in labels
        correct = the number of correct-detected characters
    '''
    total = 0
    correct = 0
    for label in labels:
        line = label.split(',')
        plate_gt = [int(x) for x in line[:4]]
        for g in outp:
            if get_iou(plate_gt, g['plate']) >= 0.5:
                detected_plate = get_str(g['char'])
                t, c = get_acc(line[-1], detected_plate)
                total += t
                correct += c
    return total, correct

def labels_len(labels):
    '''
    Compute the number of characters in ground truth.
    Input:
        labels = a list of str, i.e. ['14,71,83,105,FS799', '215,188,324,240,DP4846']
    Return:
        num = the number of characters of all plates
    '''
    num = 0
    for label in labels:
        lines = label.split(',')
        n = len(lines[-1])
        num += n
    return num

def get_wer(r, h):
    """
    Compute word_error_rate(WER) of two list of strings.
    Input:
        r = ground truth
        h = predicted results
    Return:
        result = WER (presented in percentage)
        sid = substitution + insertion + deletion
        total = the number of groundtruth
    """
    d = np.zeros((len(r) + 1) * (len(h) + 1), dtype=np.uint16)
    d = d.reshape((len(r) + 1, len(h) + 1))
    for i in range(len(r) + 1):
        for j in range(len(h) + 1):
            if i == 0:
                d[0][j] = j
            elif j == 0:
                d[i][0] = i

    for i in range(1, len(r) + 1):
        for j in range(1, len(h) + 1):
            if r[i - 1] == h[j - 1]:
                d[i][j] = d[i - 1][j - 1]
            else:
                substitution = d[i - 1][j - 1] + 1
                insertion = d[i][j - 1] + 1
                deletion = d[i - 1][j] + 1
                d[i][j] = min(substitution, insertion, deletion)
    sid = d[len(r)][len(h)]
    total = len(r)
    result = float(sid) / total * 100

    return result, sid, total

def eval_dataset(results,label_data):
    correct_plate = {}
    total_p, correct_p, pred_p = 0, 0, 0
    for k, v in label_data.items():
        gt = transfer_label(v)
        total_p += len(gt)
        if k in results:
            r = group_plate(results[k]) # r = [{'plate': int[x1, y1, x2, y2], 'char':[int[x1, y1, x2, y2, label], ...]}, ...]
            pred_p += len(r)
            correct_r = []
            for _r in r:
                for idx, bbox in enumerate(gt):
                    if get_iou(bbox, _r['plate']) >= 0.5:
                        n_r = {'plate': _r['plate'], 'char': _r['char'], 'idx': idx}
                        correct_r.append(n_r)
            num = len(correct_r)
            if num > 0:
                correct_plate[k] = correct_r
                correct_p += num
                
    print("Number of Correctly Detected Plates =", correct_p)
    print("Number of Detected Plates =", pred_p)
    print("Number of All Plates =", total_p)
    print("Recall = {:.4f}".format(correct_p/total_p))
    print("Precision = {:.4f}".format(correct_p/pred_p))

    n_perfect = 0  ### number of perfectly recognized plates
    n_sid = 0  ### number of failed recognized chars in detected
    n_detected = 0  ### number of chars in detected plates

    for k, v in label_data.items():
        gt_strs = [s.split(',')[-1] for s in v]
        if k in correct_plate:
            objs = correct_plate[k]
            for obj in objs: # obj = [{'plate': int[x1, y1, x2, y2], 'char':[int[x1, y1, x2, y2, label], ...], 'idx': int(i)}]
                pred_str = [classes[x[-1]] for x in obj['char']]
                wer, sid, t = get_wer(list(gt_strs[obj['idx']]), pred_str)
                n_sid += sid
                n_detected += t
                if wer == 0:
                    n_perfect += 1


    print("Characters in Detected Plates = ", n_detected)
    print("Error Characters (Detected) =", n_sid)
    print("World Error Rate (Detected) = {:.4f}".format(n_sid/n_detected))

    print("\nNumber of Perfectly Recognized Plates = ", n_perfect)
    print("Accuracy(Detected) = {:.4f}".format(n_perfect/correct_p))
    print("Accuracy(Groundtruth) = {:.4f}".format(n_perfect/total_p))
    
    
"""
Create label dictionary.
Format: dic = {key: file_name(str), value: [obj1(str), obj2(str), ...]}
        obj format = 'x_min, y_min, x_max, y_max, plate'
   i.e. dic['train_LE_3'] = ['266,199,350,242,2972KK']
        dic['train_LE_33'] = ['14,71,83,105,FS799', '215,188,324,240,DP4846']
"""
# Out:
# self.flags_spot_light = False
# self.flags_rain = False
# self.flags_gamma = True
# self.flags_pixelate = False
# Loaded static_model/yolov7-tiny-genbg-ep20-b64-gamma_epoch_019.pt, epoch 19
# "\nCreate label dictionary.\nFormat: dic = {key: file_name(str), value: [obj1(str), obj2(str), ...]}\n        obj format = 'x_min, y_min, x_max, y_max, plate'\n   i.e. dic['train_LE_3'] = ['266,199,350,242,2972KK']\n        dic['train_LE_33'] = ['14,71,83,105,FS799', '215,188,324,240,DP4846']\n"

# %% [markdown]
# # test AOLP

# %%
#label_txt = '/data/yolodiffusion-main/_plate/AOLP/label.txt'
#img_dir = '/data/yolodiffusion-main/_plate/AOLP/original/'
label_txt = '/data/licence_plate/_plate/AOLP/label.txt'
img_dir = '/data/licence_plate/_plate/AOLP/original/'

input_size = 1024

# %%
label_data = {}
label_file = open(label_txt, 'r')
lines = label_file.readlines()
for line in lines:
    l = line.strip().split(' ')
    name = l[0]
    plates = l[1:]
    label_data[name] = plates
    
img_paths = os.listdir(img_dir)
img_paths.sort()
#print(img_paths)
#model.create_subnetwork()
#model.before_diffusion_model.half()
#model.after_diffusion_model.half()

# %%
results_diffusion = {}
for f in tqdm(img_paths, ncols=80):
    if f.endswith('.jpg'):
        bname = os.path.splitext(f)[0]
        img_p = img_dir + f
        
        #ret, meta = run_withdiffusion(img_p)# with diffusion
        ret, meta = run(img_p)# with diffusion
        
        if ret[0] is not None:
            output = affine_transform(ret, meta) # output = [num_objs, 6(x1, y1, x2, y2, conf, cls)]
            results_diffusion[bname] = output
# Out:
# 100%|███████████████████████████████████████| 2049/2049 [01:39<00:00, 20.57it/s]

# %%
print('dataset = %s'%format(label_txt))
print('weight = %s'%format(best_state_dict))
print('input_size = %s'%format(input_size))

eval_dataset(results_diffusion,label_data)
# Out:
# dataset = /data/licence_plate/_plate/AOLP/label.txt
# weight = static_model/yolov7-tiny-genbg-ep20-b64-gamma_epoch_019_state_dict.pt
# input_size = 1024
# Number of Correctly Detected Plates = 2051
# Number of Detected Plates = 2507
# Number of All Plates = 2164
# Recall = 0.9478
# Precision = 0.8181
# Characters in Detected Plates =  12247
# Error Characters (Detected) = 1012
# World Error Rate (Detected) = 0.0826
#
# Number of Perfectly Recognized Plates =  1491
# Accuracy(Detected) = 0.7270
# Accuracy(Groundtruth) = 0.6890

# %% [markdown]
# # test WLP

# %%
#label_txt = '/data/yolodiffusion-main/_plate/WLP/label.txt'
#img_dir = '/data/yolodiffusion-main/_plate/WLP/original/'
label_txt = '/data/licence_plate/_plate/WLP/label.txt'
img_dir = '/data/licence_plate/_plate/WLP/original/'


input_size = 2048

# %%
label_data = {}
label_file = open(label_txt, 'r')
lines = label_file.readlines()
for line in lines:
    l = line.strip().split(' ')
    name = l[0]
    plates = l[1:]
    label_data[name] = plates
    
img_paths = os.listdir(img_dir)
img_paths.sort()

# %%
results_diffusion = {}
for f in tqdm(img_paths, ncols=80):
    if f.endswith('.jpg'):
        bname = os.path.splitext(f)[0]
        img_p = img_dir + f
        
        #ret, meta = run_withdiffusion(img_p)# with diffusion
        ret, meta = run(img_p)# with diffusion
        
        if ret[0] is not None:
            output = affine_transform(ret, meta) # output = [num_objs, 6(x1, y1, x2, y2, conf, cls)]
            results_diffusion[bname] = output
# Out:
# 100%|███████████████████████████████████████████| 47/47 [00:08<00:00,  5.46it/s]

# %%
print('dataset = %s'%format(label_txt))
print('weight = %s'%format(best_state_dict))
print('input_size = %s'%format(input_size))

eval_dataset(results_diffusion,label_data)
# Out:
# dataset = /data/licence_plate/_plate/WLP/label.txt
# weight = static_model/yolov7-tiny-genbg-ep20-b64-gamma_epoch_019_state_dict.pt
# input_size = 2048
# Number of Correctly Detected Plates = 43
# Number of Detected Plates = 57
# Number of All Plates = 54
# Recall = 0.7963
# Precision = 0.7544
# Characters in Detected Plates =  270
# Error Characters (Detected) = 122
# World Error Rate (Detected) = 0.4519
#
# Number of Perfectly Recognized Plates =  10
# Accuracy(Detected) = 0.2326
# Accuracy(Groundtruth) = 0.1852
